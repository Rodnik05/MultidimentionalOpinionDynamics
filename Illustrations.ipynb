# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt


df = pd.read_csv("Opinions/Opinions1.txt")

AgentsCount = df.shape[1] - 2

for i in range(AgentsCount):
    plt.plot(df['iteration'], df[str(i)])

plt.show()
